# %% [markdown]
# # illustrating the input shape, output shape and hierarchical view of each model
# Summary of each model and its parameters

# %%
# !pip install pytorch-model-summary

# %%
import torch
from torch import nn, optim
from torchvision import datasets ,transforms, models
import numpy as np
import matplotlib.pyplot as plt
import helper
import math
import time as evaltime
from torch import nn
from collections import OrderedDict
# !pip install pretrainedmodels
import pretrainedmodels
import tqdm
from tqdm import tqdm
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

from pytorch_model_summary import summary

# %% [markdown]
# # Inceptionresnetv2

# %%
inceptionresnetv2 = 'inceptionresnetv2' # could be fbresnet152 or inceptionresnetv2
Inception_Res_V2 = pretrainedmodels.__dict__[inceptionresnetv2](num_classes=1000, pretrained=False)

# %%
classifier= nn.Sequential(OrderedDict([
    ('0', nn.Linear(1536,1024)),
    ('1',nn.ReLU(inplace=True)),
    ('2', nn.Dropout(p=0.5)),
    ('3', nn.Linear(1024,1024)),
    ('4',nn.ReLU(inplace=True)),
    ('5', nn.Dropout(p=0.5)),
    ('6', nn.Linear(1024,2)),
    ('output', nn.LogSoftmax(dim=1))
    
]))
Inception_Res_V2.last_linear=classifier
for params in Inception_Res_V2.parameters():
    params.required_grad=False
for params in Inception_Res_V2.last_linear.parameters():
    params.required_grad=True

# %%
# size of the input
input=(32, 3, 299, 299)
Net=Inception_Res_V2


# show output shape and hierarchical view of net
print(summary(Net, torch.zeros(input), show_input=False, show_hierarchical=True))
# Out:
# --------------------------------------------------------------------------
#       Layer (type)            Input Shape         Param #     Tr. Param #
# ...
#      BasicConv2d-1      [32, 3, 299, 299]             928             928
#      BasicConv2d-2     [32, 32, 149, 149]           9,280           9,280
#      BasicConv2d-3     [32, 32, 147, 147]          18,560          18,560
#        MaxPool2d-4     [32, 64, 147, 147]               0               0
#      BasicConv2d-5       [32, 64, 73, 73]           5,280           5,280
#      BasicConv2d-6       [32, 80, 73, 73]         138,624         138,624
#        MaxPool2d-7      [32, 192, 71, 71]               0               0
#         Mixed_5b-8      [32, 192, 35, 35]         268,320         268,320
#          Block35-9      [32, 320, 35, 35]         123,168         123,168
#         Block35-10      [32, 320, 35, 35]         123,168         123,168
#         Block35-11      [32, 320, 35, 35]         123,168         123,168
# ...

# %% [markdown]
# # Dpn131

# %%
dpn131 = 'dpn131' 
dpn131_ = pretrainedmodels.__dict__[dpn131](num_classes=1000, pretrained=False)
dpn131_c2=dpn131_
classifier= nn.Sequential(OrderedDict([
    ('0',nn.Conv2d(2688, 2, kernel_size=(1, 1), stride=(1, 1))),
    # ('0', nn.AdaptiveAvgPool2d(output_size=(1, 1))),
    # ('1', nn.Linear(2688 ,1024)),
    # ('2',nn.ReLU(inplace=True)),
    # ('3', nn.Dropout(p=0.5)),
    # ('4', nn.Linear(1024,1024)),
    # ('5',nn.ReLU(inplace=True)),
    # ('6', nn.Dropout(p=0.5)),
    # ('7', nn.Linear(1024,2)),
    ('output', nn.LogSoftmax(dim=1))
    
]))

dpn131_c2.last_linear=classifier
input=(32, 3, 224, 224)
Net=dpn131_c2


# show output shape and hierarchical view of net
print(summary(Net, torch.zeros(input), show_input=False, show_hierarchical=True))
# Out:
# ----------------------------------------------------------------------------------------------
#        Layer (type)                              Output Shape         Param #     Tr. Param #
# ...
#        InputBlock-1                         [32, 128, 56, 56]          19,072          19,072
#     DualPathBlock-2       [32, 256, 56, 56], [32, 48, 56, 56]         107,776         107,776
#     DualPathBlock-3       [32, 256, 56, 56], [32, 64, 56, 56]          99,168          99,168
#     DualPathBlock-4       [32, 256, 56, 56], [32, 80, 56, 56]         101,760         101,760
#     DualPathBlock-5       [32, 256, 56, 56], [32, 96, 56, 56]         104,352         104,352
#     DualPathBlock-6       [32, 512, 28, 28], [32, 96, 28, 28]         515,200         515,200
#     DualPathBlock-7      [32, 512, 28, 28], [32, 128, 28, 28]         394,176         394,176
#     DualPathBlock-8      [32, 512, 28, 28], [32, 160, 28, 28]         404,480         404,480
# ...

# %% [markdown]
# # Senet154

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
senet154 = 'senet154' 
SeNet154_2c = pretrainedmodels.__dict__[senet154](num_classes=1000)
classifier= nn.Sequential(OrderedDict([
    ('0', nn.Linear(2048,1024)),
    ('1',nn.ReLU(inplace=True)),
    ('2', nn.Dropout(p=0.5)),
    ('3', nn.Linear(1024,1024)),
    ('4',nn.ReLU(inplace=True)),
    ('5', nn.Dropout(p=0.5)),
    ('6', nn.Linear(1024,2)),
    ('output', nn.LogSoftmax(dim=1))
    
]))
SeNet154_2c.last_linear=classifier
for params in SeNet154_2c.parameters():
    params.required_grad=False
for params in SeNet154_2c.last_linear.parameters():
    params.required_grad=True
input=(32, 3, 224, 224)
Net=SeNet154_2c


# show output shape and hierarchical view of net
print(summary(Net, torch.zeros(input), show_input=False, show_hierarchical=True))
# Out:
# Downloading: "http://data.lip6.fr/cadene/pretrainedmodels/senet154-c7b49a05.pth" to /root/.cache/torch/checkpoints/senet154-c7b49a05.pth
# ...
# ---------------------------------------------------------------------------
#       Layer (type)            Output Shape         Param #     Tr. Param #
# ...
#           Conv2d-1      [32, 64, 112, 112]           1,728           1,728
#      BatchNorm2d-2      [32, 64, 112, 112]             128             128
#             ReLU-3      [32, 64, 112, 112]               0               0
#           Conv2d-4      [32, 64, 112, 112]          36,864          36,864
#      BatchNorm2d-5      [32, 64, 112, 112]             128             128
#             ReLU-6      [32, 64, 112, 112]               0               0
#           Conv2d-7     [32, 128, 112, 112]          73,728          73,728
#      BatchNorm2d-8     [32, 128, 112, 112]             256             256
#             ReLU-9     [32, 128, 112, 112]               0               0
# ...

# %% [markdown]
# # Nasnetalarge

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
nasnetalarge = 'nasnetalarge' # could be fbresnet152 or inceptionresnetv2
nasnetalarge_2c = pretrainedmodels.__dict__[nasnetalarge](num_classes=1000)
classifier= nn.Sequential(OrderedDict([
    ('0', nn.Linear(4032,1024)),
    ('1',nn.ReLU(inplace=True)),
    ('2', nn.Dropout(p=0.5)),
    ('3', nn.Linear(1024,1024)),
    ('4',nn.ReLU(inplace=True)),
    ('5', nn.Dropout(p=0.5)),
    ('6', nn.Linear(1024,2)),
    ('output', nn.LogSoftmax(dim=1))
    
]))
nasnetalarge_2c.last_linear=classifier
for params in nasnetalarge_2c.parameters():
    params.required_grad=False
for params in nasnetalarge_2c.last_linear.parameters():
    params.required_grad=True

input=(32, 3, 224, 224)
Net=nasnetalarge_2c


# show output shape and hierarchical view of net
print(summary(Net, torch.zeros(input), show_input=False, show_hierarchical=True))
# Out:
# Downloading: "http://data.lip6.fr/cadene/pretrainedmodels/nasnetalarge-a1897284.pth" to /root/.cache/torch/checkpoints/nasnetalarge-a1897284.pth
# ...

# %% [markdown]
# # ResNext101_32x8d

# %%
ResNext101_2c= models.resnext101_32x8d(pretrained=False)
for params in ResNext101_2c.parameters():
    params.required_grad=False
classifier= nn.Sequential(OrderedDict([
    ('0', nn.Linear(2048,1024)),
    ('1',nn.ReLU(inplace=True)),
    ('2', nn.Dropout(p=0.5)),
    ('3', nn.Linear(1024,1024)),
    ('4',nn.ReLU(inplace=True)),
    ('5', nn.Dropout(p=0.5)),
    ('6', nn.Linear(1024,2)),
    ('output', nn.LogSoftmax(dim=1))
    
]))
ResNext101_2c.fc=classifier
for params in ResNext101_2c.fc.parameters():
    params.required_grad=True

input=(32, 3, 256, 256)
Net=ResNext101_2c


# show output shape and hierarchical view of net
print(summary(Net, torch.zeros(input), show_input=False, show_hierarchical=True))
# Out:
# -------------------------------------------------------------------------------
#            Layer (type)           Output Shape         Param #     Tr. Param #
# ...
#                Conv2d-1     [32, 64, 128, 128]           9,408           9,408
#           BatchNorm2d-2     [32, 64, 128, 128]             128             128
#                  ReLU-3     [32, 64, 128, 128]               0               0
#             MaxPool2d-4       [32, 64, 64, 64]               0               0
#            Bottleneck-5      [32, 256, 64, 64]         118,784         118,784
#            Bottleneck-6      [32, 256, 64, 64]         151,040         151,040
#            Bottleneck-7      [32, 256, 64, 64]         151,040         151,040
#            Bottleneck-8      [32, 512, 32, 32]         602,112         602,112
#            Bottleneck-9      [32, 512, 32, 32]         601,088         601,088
#           Bottleneck-10      [32, 512, 32, 32]         601,088         601,088
# ...

# %% [markdown]
# # Resnext101_64x4d

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
resnext101_64x4d = 'resnext101_64x4d' # could be fbresnet152 or inceptionresnetv2
ResNext101_2c = pretrainedmodels.__dict__[resnext101_64x4d](num_classes=1000)
classifier= nn.Sequential(OrderedDict([
    ('0', nn.Linear(2048,1024)),
    ('1',nn.ReLU(inplace=True)),
    ('2', nn.Dropout(p=0.5)),
    ('3', nn.Linear(1024,1024)),
    ('4',nn.ReLU(inplace=True)),
    ('5', nn.Dropout(p=0.5)),
    ('6', nn.Linear(1024,2)),
    ('output', nn.LogSoftmax(dim=1))
    
]))
ResNext101_2c.last_linear=classifier
for params in ResNext101_2c.parameters():
    params.required_grad=False
for params in ResNext101_2c.last_linear.parameters():
    params.required_grad=True
input=(32, 3, 224, 224)
Net=ResNext101_2c


# show output shape and hierarchical view of net
print(summary(Net, torch.zeros(input), show_input=False, show_hierarchical=True))
# Out:
# Downloading: "http://data.lip6.fr/cadene/pretrainedmodels/resnext101_64x4d-e77a0586.pth" to /root/.cache/torch/checkpoints/resnext101_64x4d-e77a0586.pth
# ...
# --------------------------------------------------------------------------
#       Layer (type)           Output Shape         Param #     Tr. Param #
# ...
#           Conv2d-1     [32, 64, 112, 112]           9,408           9,408
#      BatchNorm2d-2     [32, 64, 112, 112]             128             128
#             ReLU-3     [32, 64, 112, 112]               0               0
#        MaxPool2d-4       [32, 64, 56, 56]               0               0
#           Conv2d-5      [32, 256, 56, 56]          16,384          16,384
#      BatchNorm2d-6      [32, 256, 56, 56]             512             512
#             ReLU-7      [32, 256, 56, 56]               0               0
#           Conv2d-8      [32, 256, 56, 56]           9,216           9,216
#      BatchNorm2d-9      [32, 256, 56, 56]             512             512
# ...
